# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)
data = pd.read_csv(r"C:\Users\lenovo\Downloads\data.csv")

toss = data["toss_decision"].value_counts()
label = toss.index
counts = toss.values
mylabel=['field','bat']
plt.pie(toss,labels=mylabel)

plt.show()

data2=data.groupby(['team1','team2']).size()

print(data2)
data["winner"].value_counts().plot(kind= "bar")
man_of_the_match=data['player_of_match'].value_counts()
print(man_of_the_match)
data['player_of_match'].value_counts().plot(kind='bar',figsize=(30,10))
# Out:
# team1                team2
# Chennai Super Kings  Deccan Chargers                 8
#                      Delhi Daredevils               11
#                      Kings XI Punjab                 9
#                      Kochi Tuskers Kerala            2
#                      Kolkata Knight Riders          11
#                                                     ..
# Sunrisers Hyderabad  Mumbai Indians                  5
#                      Pune Warriors                   2
#                      Rajasthan Royals                7
#                      Rising Pune Supergiants         2
#                      Royal Challengers Bangalore     5
# Length: 113, dtype: int64
# player_of_match
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
#                   ..
# MN Samuels         1
# S Badrinath        1
# R Bhatia           1
# RE Levi            1
# BCJ Cutting        1
# Name: count, Length: 187, dtype: int64
# ...
